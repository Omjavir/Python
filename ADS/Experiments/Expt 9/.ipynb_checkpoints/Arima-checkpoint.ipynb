# %%
import pandas as pd
import numpy as np
from datetime import datetime
# Out:
# Running cells with 'Python 3.12.1' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/OM/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
df = pd.read_csv('../IT_Salary_Survey.csv')
df.head()
# Out:
#      Country of Nationality  2014 1st quarter (Jan-March)  \
# 0                    Canada                          33.1
# 1  United States Of America                          25.7
# 2                 Argentina                          46.8
# 3                    Brazil                          31.0
# 4                    Mexico                          23.6
#
#    2014 2nd quarter (Apr-June)  2014 3rd quarter (July-Sep)  \
# 0                         14.5                         15.7
# 1                         22.0                         20.6
# 2                         15.6                         13.9
# 3                         18.8                         18.7
# 4                         20.3                         26.5
#
#    2014 4th quarter (Oct-Dec))  2015 1st quarter (Jan-March)  \
# 0                         36.7                          34.2
# 1                         31.7                          26.4
# 2                         23.7                          40.6
# 3                         31.5                          34.8
# 4                         29.6                          28.1
#
#    2015 2nd quarter (Apr-June)  2015 3rd quarter (July-Sep)  \
# 0                         14.5                         15.9
# 1                         22.1                         19.6
# 2                         17.5                         14.6
# 3                         19.0                         19.6
# 4                         21.3                         23.4
#
#    2015 4th quarter (Oct-Dec)  2016 1st quarter (Jan-March)  ...  \
# 0                        35.4                          34.5  ...
# 1                        31.9                          25.7  ...
# 2                        27.3                          41.7  ...
# 3                        26.6                          29.7  ...
# 4                        27.2                          25.4  ...
#
#    2018 3rd quarter (July-Sep)  2018 4th quarter (Oct-Dec)  \
# 0                        16.19                       32.94
# 1                        20.23                       31.22
# 2                        15.71                       20.22
# 3                        18.95                       28.00
# 4                        22.60                       31.34
#
#    2019 1st quarter (Jan-March)  2019 2nd quarter (Apr-June)  \
# 0                          36.4                         14.3
# 1                          26.9                         21.4
# 2                          41.5                         16.8
# 3                          32.1                         19.5
# 4                          25.0                         21.8
#
#    2019 3rd quarter (July-Sep)  2019 4th quarter (Oct-Dec)  \
# 0                         14.8                        34.5
# 1                         19.3                        32.3
# 2                         16.7                        25.1
# 3                         18.7                        29.7
# 4                         21.9                        31.2
#
#    2020 1st quarter (Jan-March)  2020 2nd quarter (Apr-June)  \
# 0                          88.9                          0.3
# 1                          84.5                          0.9
# 2                          97.8                          0.2
# 3                          92.6                          0.9
# 4                          95.8                          0.5
#
#    2020 3rd quarter (July-Sep)  2020 4th quarter (Oct-Dec)
# 0                          2.0                         8.8
# 1                          3.8                        10.8
# 2                          0.5                         1.5
# 3                          2.3                         4.1
# 4                          1.2                         2.4
#
# [5 rows x 29 columns]

# %%
def parser(x):
    return datetime.strptime(x, '%Y-%m')

def getDate(x):
    d = x.split(' ')[0: 2]
    d[1] = str(int(d[1][0])*3)
    print(parser("-".join(d)))
#     print(d)

# %%
for series_name, series in df.items():
    if series_name == 'Country of Nationality': continue
    getDate(series_name)

new_df = pd.DataFrame()
for series_name, series in df.T.items():
#     print(series_name)
    if series_name == 1:
        new_df[series_name] = series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [79], line 3
#       1 for series_name, series in df.items():
#       2     if series_name == 'Country of Nationality': continue
# ----> 3     getDate(series_name)
#       5 new_df = pd.DataFrame()
#       6 for series_name, series in df.T.items():
#       7 #     print(series_name)
#
# Cell In [78], line 7, in getDate(x)
#       5 d = x.split(' ')[0: 2]
#       6 d[1] = str(int(d[1][0])*3)
# ----> 7 print(parser("-".join(d)))
#
# Cell In [78], line 2, in parser(x)
#       1 def parser(x):
# ----> 2     return datetime.strptime(x, '%Y-%m-%d')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\_strptime.py:349, in _strptime(data_string, format)
#     347 found = format_regex.match(data_string)
#     348 if not found:
# --> 349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
#     352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#
# ValueError: time data '2014-3' does not match format '%Y-%m-%d'

# %%
y = list(new_df[1])[1:]

# %%
# Out:
# Country of Nationality          Canada
# 2014 1st quarter (Jan-March)      33.1
# 2014 2nd quarter (Apr-June)       14.5
# 2014 3rd quarter (July-Sep)       15.7
# 2014 4th quarter (Oct-Dec))       36.7
# 2015 1st quarter (Jan-March)      34.2
# 2015 2nd quarter (Apr-June)       14.5
# 2015 3rd quarter (July-Sep)       15.9
# 2015 4th quarter (Oct-Dec)        35.4
# 2016 1st quarter (Jan-March)      34.5
# 2016 2nd quarter (Apr-June)       14.1
# 2016 3rd quarter (July-Sep)       16.5
# 2016 4th quarter (Oct-Dec)        34.9
# 2017 1st quarter (Jan-March)      33.9
# 2017 2nd quarter (Apr-June)       13.9
# 2017 3rd quarter (July-Sep)       16.9
# 2017 4th quarter (Oct-Dec)        35.3
# 2018 1st quarter (Jan-March)     36.72
# 2018 2nd quarter (Apr-June)      14.14
# 2018 3rd quarter (July-Sep)      16.19
# 2018 4th quarter (Oct-Dec)       32.94
# 2019 1st quarter (Jan-March)      36.4
# 2019 2nd quarter (Apr-June)       14.3
# 2019 3rd quarter (July-Sep)       14.8
# 2019 4th quarter (Oct-Dec)        34.5
# 2020 1st quarter (Jan-March)      88.9
# 2020 2nd quarter (Apr-June)        0.3
# 2020 3rd quarter (July-Sep)        2.0
# 2020 4th quarter (Oct-Dec)         8.8
# Name: 0, dtype: object
